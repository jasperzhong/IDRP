# %%
# !python train.py
# Out:
# cuda is available
# Training from scratch!
# train.py:33: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   torch.nn.init.normal(m.weight.data,mean=0,std=0.1)
# train.py:34: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   torch.nn.init.constant(m.bias.data, 0.1)
# Start training!
# Epoch 0 train loss: 0.013  time: 15.384 s
# Epoch 0 dev f1: 0.061
# Model save!
# Epoch 1 train loss: 0.006  time: 15.069 s
# Epoch 1 dev f1: 0.061
# Model save!
# Epoch 2 train loss: 0.004  time: 16.596 s
# Epoch 2 dev f1: 0.057
# Epoch 3 train loss: 0.003  time: 14.831 s
# Epoch 3 dev f1: 0.047
# Epoch 4 train loss: 0.003  time: 14.892 s
# Epoch 4 dev f1: 0.056
# Epoch 5 train loss: 0.002  time: 14.781 s
# Epoch 5 dev f1: 0.095
# Model save!
# Epoch 6 train loss: 0.002  time: 14.817 s
# Epoch 6 dev f1: 0.064
# Epoch 7 train loss: 0.002  time: 14.956 s
# Epoch 7 dev f1: 0.053
# Epoch 8 train loss: 0.002  time: 16.015 s
# ...
