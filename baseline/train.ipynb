# %%
# !python train.py
# Out:
# cuda is available
# Training from scratch!
# train.py:33: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   torch.nn.init.normal(m.weight.data,mean=0,std=0.1)
# train.py:34: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.
#   torch.nn.init.constant(m.bias.data, 0.1)
# Start training!
# Epoch 0 train loss: 0.028  time: 12.943 s
#              precision    recall  f1-score   support
#
#           0       0.15      0.44      0.22       196
#           1       0.27      0.17      0.20       303
#           2       0.79      0.07      0.13      1122
#           3       0.04      0.57      0.07        53
#
# avg / total       0.59      0.15      0.15      1674
#
# Epoch 1 train loss: 0.027  time: 11.026 s
#              precision    recall  f1-score   support
#
#           0       0.16      0.37      0.22       196
#           1       0.32      0.17      0.22       303
#           2       0.74      0.32      0.44      1122
# ...
