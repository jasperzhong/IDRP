# %%
# !python train.py
# Out:
# cuda is available
# Training from scratch!
# Epoch 0 train loss: 0.022  time: 19.013 s
# /home/zyc/.conda/envs/zyc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00       197
#           1       0.00      0.00      0.00       308
#           2       0.67      1.00      0.80      1148
#           3       0.00      0.00      0.00        54
#
# avg / total       0.45      0.67      0.54      1707
#
# Epoch 1 train loss: 0.022  time: 19.201 s
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00       197
#           1       0.00      0.00      0.00       308
#           2       0.67      1.00      0.80      1148
# ...
